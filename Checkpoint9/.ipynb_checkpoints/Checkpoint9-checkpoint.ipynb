# %%
#Importation
import pandas as pd
import mlxtend
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
#Dataset

# %%
dataset = [['Skirt', 'Sneakers', 'Scarf', 'Pants', 'Hat'],
           ['Sunglasses', 'Skirt', 'Sneakers', 'Pants', 'Hat'],
           ['Dress', 'Sandals', 'Scarf', 'Pants', 'Heels'],
           ['Dress', 'Necklace', 'Earrings', 'Scarf', 'Hat', 'Heels', 'Hat'],
           ['Earrings', 'Skirt', 'Skirt', 'Scarf', 'Shirt', 'Pants']]

# %%
#Convertir la liste en valeurs booléennes
te = TransactionEncoder()
te_ary = te.fit(dataset).transform(dataset)
df = pd.DataFrame(te_ary,columns=te.columns_)
df
# Out:
#    Dress  Earrings    Hat  Heels  Necklace  Pants  Sandals  Scarf  Shirt  \
# 0  False     False   True  False     False   True    False   True  False
# 1  False     False   True  False     False   True    False  False  False
# 2   True     False  False   True     False   True     True   True  False
# 3   True      True   True   True      True  False    False   True  False
# 4  False      True  False  False     False   True    False   True   True
#
#    Skirt  Sneakers  Sunglasses
# 0   True      True       False
# 1   True      True        True
# 2  False     False       False
# 3  False     False       False
# 4   True     False       False

# %%
apriori(df)
# Out:
#    support itemsets
# 0      0.6      (2)
# 1      0.8      (5)
# 2      0.8      (7)
# 3      0.6      (9)
# 4      0.6   (5, 7)
# 5      0.6   (9, 5)

# %%
frequent_itemsets = apriori(df,min_support=0.1,use_colnames=True)
frequent_itemsets
# Out:
#      support                                        itemsets
# 0        0.4                                         (Dress)
# 1        0.4                                      (Earrings)
# 2        0.6                                           (Hat)
# 3        0.4                                         (Heels)
# 4        0.2                                      (Necklace)
# ..       ...                                             ...
# 146      0.2         (Hat, Necklace, Scarf, Heels, Earrings)
# 147      0.2          (Scarf, Skirt, Earrings, Shirt, Pants)
# 148      0.2            (Hat, Scarf, Sneakers, Skirt, Pants)
# 149      0.2       (Hat, Sneakers, Skirt, Sunglasses, Pants)
# 150      0.2  (Hat, Necklace, Scarf, Dress, Heels, Earrings)
#
# [151 rows x 2 columns]

# %%
association_rules(frequent_itemsets,metric="confidence",min_threshold=0.7)
# Out:
#               antecedents                           consequents  \
# 0                 (Heels)                               (Dress)
# 1                 (Dress)                               (Heels)
# 2              (Necklace)                               (Dress)
# 3               (Sandals)                               (Dress)
# 4                 (Dress)                               (Scarf)
# ..                    ...                                   ...
# 670     (Necklace, Heels)         (Hat, Scarf, Dress, Earrings)
# 671  (Necklace, Earrings)            (Hat, Scarf, Dress, Heels)
# 672     (Earrings, Dress)         (Hat, Necklace, Scarf, Heels)
# 673     (Heels, Earrings)         (Hat, Necklace, Scarf, Dress)
# 674            (Necklace)  (Hat, Scarf, Dress, Heels, Earrings)
#
#      antecedent support  consequent support  support  confidence  lift  \
# 0                   0.4                 0.4      0.4         1.0  2.50
# 1                   0.4                 0.4      0.4         1.0  2.50
# 2                   0.2                 0.4      0.2         1.0  2.50
# 3                   0.2                 0.4      0.2         1.0  2.50
# 4                   0.4                 0.8      0.4         1.0  1.25
# ..                  ...                 ...      ...         ...   ...
# 670                 0.2                 0.2      0.2         1.0  5.00
# 671                 0.2                 0.2      0.2         1.0  5.00
# 672                 0.2                 0.2      0.2         1.0  5.00
# 673                 0.2                 0.2      0.2         1.0  5.00
# 674                 0.2                 0.2      0.2         1.0  5.00
#
#      leverage  conviction
# 0        0.24         inf
# 1        0.24         inf
# 2        0.12         inf
# 3        0.12         inf
# 4        0.08         inf
# ..        ...         ...
# 670      0.16         inf
# 671      0.16         inf
# 672      0.16         inf
# 673      0.16         inf
# 674      0.16         inf
#
# [675 rows x 9 columns]

# %%
association_rules(frequent_itemsets,metric="lift",min_threshold=1)
# Out:
#      antecedents                              consequents  antecedent support  \
# 0     (Earrings)                                  (Dress)                 0.4
# 1        (Dress)                               (Earrings)                 0.4
# 2        (Heels)                                  (Dress)                 0.4
# 3        (Dress)                                  (Heels)                 0.4
# 4     (Necklace)                                  (Dress)                 0.2
# ...          ...                                      ...                 ...
# 1135  (Necklace)     (Hat, Scarf, Dress, Heels, Earrings)                 0.2
# 1136     (Scarf)  (Hat, Necklace, Dress, Heels, Earrings)                 0.8
# 1137     (Dress)  (Hat, Necklace, Scarf, Heels, Earrings)                 0.4
# 1138     (Heels)  (Hat, Necklace, Scarf, Dress, Earrings)                 0.4
# 1139  (Earrings)     (Hat, Necklace, Scarf, Dress, Heels)                 0.4
#
#       consequent support  support  confidence  lift  leverage  conviction
# 0                    0.4      0.2        0.50  1.25      0.04    1.200000
# 1                    0.4      0.2        0.50  1.25      0.04    1.200000
# 2                    0.4      0.4        1.00  2.50      0.24         inf
# 3                    0.4      0.4        1.00  2.50      0.24         inf
# 4                    0.4      0.2        1.00  2.50      0.12         inf
# ...                  ...      ...         ...   ...       ...         ...
# 1135                 0.2      0.2        1.00  5.00      0.16         inf
# 1136                 0.2      0.2        0.25  1.25      0.04    1.066667
# 1137                 0.2      0.2        0.50  2.50      0.12    1.600000
# 1138                 0.2      0.2        0.50  2.50      0.12    1.600000
# 1139                 0.2      0.2        0.50  2.50      0.12    1.600000
#
# [1140 rows x 9 columns]

# %%
#GRAND Dataset

# %%
#Importation du Dataset
data=pd.read_csv('Market_Basket_Optimisation.csv',header=None)
data.head()
# Out:
#               0          1           2                 3             4   \
# 0         shrimp    almonds     avocado    vegetables mix  green grapes
# 1        burgers  meatballs        eggs               NaN           NaN
# 2        chutney        NaN         NaN               NaN           NaN
# 3         turkey    avocado         NaN               NaN           NaN
# 4  mineral water       milk  energy bar  whole wheat rice     green tea
#
#                  5     6               7             8             9   \
# 0  whole weat flour  yams  cottage cheese  energy drink  tomato juice
# 1               NaN   NaN             NaN           NaN           NaN
# 2               NaN   NaN             NaN           NaN           NaN
# 3               NaN   NaN             NaN           NaN           NaN
# 4               NaN   NaN             NaN           NaN           NaN
#
#                10         11     12     13             14      15  \
# 0  low fat yogurt  green tea  honey  salad  mineral water  salmon
# 1             NaN        NaN    NaN    NaN            NaN     NaN
# 2             NaN        NaN    NaN    NaN            NaN     NaN
# 3             NaN        NaN    NaN    NaN            NaN     NaN
# 4             NaN        NaN    NaN    NaN            NaN     NaN
#
#                   16               17       18         19
# 0  antioxydant juice  frozen smoothie  spinach  olive oil
# 1                NaN              NaN      NaN        NaN
# 2                NaN              NaN      NaN        NaN
# 3                NaN              NaN      NaN        NaN
# 4                NaN              NaN      NaN        NaN

# %%
#Visualisation des fréquences d'achat des articles 
plt.figure(figsize=(25,10))
graph1 = data[0].value_counts()
sns.displot(graph1)
#plt.xticks(rotation=50)
plt.title("Fréquence d'achat des articles")
plt.show()

# %%
#Visualisation des 20 articles achetés le plus fréquemment
plt.figure(figsize=(25,14))
graph2 = data[0].value_counts().head(20)
graph2.plot.bar()
plt.xticks(rotation = 45)
plt.title("Les 20 articles le plus acheté")
plt.show()

# %%
#Transformation du dataset en tableau numpy
items_list = []
for i in range(data.shape[0]):
    items_list.append([str(data_MBO.values[i,j]) for j in range(data.shape[1])])
    
tab_numpy = np.array(items_list)
tab_numpy.shape
# Out:
# (7501, 20)

# %%
#Conversion de la liste en valeurs booléennes
te = TransactionEncoder()
df = te.fit_transform(tab_numpy)
df = pd.DataFrame(df,columns=te.columns_)
df.head()
# Out:
#     asparagus  almonds  antioxydant juice  asparagus  avocado  babies food  \
# 0       False     True               True      False     True        False
# 1       False    False              False      False    False        False
# 2       False    False              False      False    False        False
# 3       False    False              False      False     True        False
# 4       False    False              False      False    False        False
#
#    bacon  barbecue sauce  black tea  blueberries  ...  turkey  vegetables mix  \
# 0  False           False      False        False  ...   False            True
# 1  False           False      False        False  ...   False           False
# 2  False           False      False        False  ...   False           False
# 3  False           False      False        False  ...    True           False
# 4  False           False      False        False  ...   False           False
#
#    water spray  white wine  whole weat flour  whole wheat pasta  \
# 0        False       False              True              False
# 1        False       False             False              False
# 2        False       False             False              False
# 3        False       False             False              False
# 4        False       False             False              False
#
#    whole wheat rice   yams  yogurt cake  zucchini
# 0             False   True        False     False
# 1             False  False        False     False
# 2             False  False        False     False
# 3             False  False        False     False
# 4              True  False        False     False
#
# [5 rows x 121 columns]

# %%
frequent_itemsets = apriori(df,min_support=0.01,use_colnames=True)
frequent_itemsets
# Out:
#       support                                      itemsets
# 0    0.020397                                     (almonds)
# 1    0.033329                                     (avocado)
# 2    0.010799                              (barbecue sauce)
# 3    0.014265                                   (black tea)
# 4    0.011465                                  (body spray)
# ..        ...                                           ...
# 510  0.011065       (mineral water, milk, ground beef, nan)
# 511  0.017064  (mineral water, ground beef, spaghetti, nan)
# 512  0.015731         (mineral water, milk, spaghetti, nan)
# 513  0.010265    (olive oil, mineral water, spaghetti, nan)
# 514  0.011465     (pancakes, mineral water, spaghetti, nan)
#
# [515 rows x 2 columns]

# %%
association_rules(frequent_itemsets,metric='confidence',min_threshold=0.7)
# Out:
#                                  antecedents consequents  antecedent support  \
# 0                                  (almonds)       (nan)            0.020397
# 1                                  (avocado)       (nan)            0.033329
# 2                           (barbecue sauce)       (nan)            0.010799
# 3                                (black tea)       (nan)            0.014265
# 4                               (body spray)       (nan)            0.011465
# ..                                       ...         ...                 ...
# 252       (mineral water, milk, ground beef)       (nan)            0.011065
# 253  (mineral water, spaghetti, ground beef)       (nan)            0.017064
# 254         (mineral water, milk, spaghetti)       (nan)            0.015731
# 255    (olive oil, mineral water, spaghetti)       (nan)            0.010265
# 256     (pancakes, mineral water, spaghetti)       (nan)            0.011465
#
#      consequent support   support  confidence      lift  leverage  conviction
# 0              0.999867  0.020264    0.993464  0.993597 -0.000131    0.020397
# 1              0.999867  0.033196    0.996000  0.996133 -0.000129    0.033329
# 2              0.999867  0.010799    1.000000  1.000133  0.000001         inf
# 3              0.999867  0.014265    1.000000  1.000133  0.000002         inf
# 4              0.999867  0.011465    1.000000  1.000133  0.000002         inf
# ..                  ...       ...         ...       ...       ...         ...
# 252            0.999867  0.011065    1.000000  1.000133  0.000001         inf
# 253            0.999867  0.017064    1.000000  1.000133  0.000002         inf
# 254            0.999867  0.015731    1.000000  1.000133  0.000002         inf
# 255            0.999867  0.010265    1.000000  1.000133  0.000001         inf
# 256            0.999867  0.011465    1.000000  1.000133  0.000002         inf
#
# [257 rows x 9 columns]

# %%
association_rules(frequent_itemsets,metric= "lift",min_threshold = 1)
# Out:
#            antecedents                           consequents  \
# 0            (avocado)                       (mineral water)
# 1      (mineral water)                             (avocado)
# 2     (barbecue sauce)                                 (nan)
# 3                (nan)                      (barbecue sauce)
# 4          (black tea)                                 (nan)
# ...                ...                                   ...
# 1677  (spaghetti, nan)             (pancakes, mineral water)
# 1678        (pancakes)       (mineral water, spaghetti, nan)
# 1679   (mineral water)            (pancakes, spaghetti, nan)
# 1680       (spaghetti)        (pancakes, mineral water, nan)
# 1681             (nan)  (pancakes, mineral water, spaghetti)
#
#       antecedent support  consequent support   support  confidence      lift  \
# 0               0.033329            0.238368  0.011598    0.348000  1.459926
# 1               0.238368            0.033329  0.011598    0.048658  1.459926
# 2               0.010799            0.999867  0.010799    1.000000  1.000133
# 3               0.999867            0.010799  0.010799    0.010800  1.000133
# 4               0.014265            0.999867  0.014265    1.000000  1.000133
# ...                  ...                 ...       ...         ...       ...
# 1677            0.174110            0.033729  0.011465    0.065850  1.952333
# 1678            0.095054            0.059725  0.011465    0.120617  2.019529
# 1679            0.238368            0.025197  0.011465    0.048098  1.908923
# 1680            0.174110            0.033729  0.011465    0.065850  1.952333
# 1681            0.999867            0.011465  0.011465    0.011467  1.000133
#
#       leverage  conviction
# 0     0.003654    1.168147
# 1     0.003654    1.016113
# 2     0.000001         inf
# 3     0.000001    1.000001
# 4     0.000002         inf
# ...        ...         ...
# 1677  0.005593    1.034385
# 1678  0.005788    1.069244
# 1679  0.005459    1.024059
# 1680  0.005593    1.034385
# 1681  0.000002    1.000002
#
# [1682 rows x 9 columns]
